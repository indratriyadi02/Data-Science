# %% [markdown]
# # **Klasifikasi Banyak Kelas**
#
# Menggunakan Iris Dataset

# %% [markdown]
# Modul Flask : https://drive.google.com/file/d/1DU46eQV8FvYBKaThFtCqe-aMVbB_R34q/view?usp=sharing

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder, LabelBinarizer, StandardScaler
from sklearn import datasets

# %%
df = pd.read_csv('/content/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = df.drop(['Id'], axis=1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
category = pd.get_dummies(df.Species)
category
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %%
new_df = pd.concat([df, category], axis=1)
new_df = new_df.drop(columns='Species')
new_df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Iris-setosa  \
# 0              5.1           3.5            1.4           0.2            1
# 1              4.9           3.0            1.4           0.2            1
# 2              4.7           3.2            1.3           0.2            1
# 3              4.6           3.1            1.5           0.2            1
# 4              5.0           3.6            1.4           0.2            1
# ..             ...           ...            ...           ...          ...
# 145            6.7           3.0            5.2           2.3            0
# 146            6.3           2.5            5.0           1.9            0
# 147            6.5           3.0            5.2           2.0            0
# 148            6.2           3.4            5.4           2.3            0
# 149            5.9           3.0            5.1           1.8            0
#
#      Iris-versicolor  Iris-virginica
# ...

# %%
dataset = new_df.values
dataset
# Out:
# array([[5.1, 3.5, 1.4, ..., 1. , 0. , 0. ],
#        [4.9, 3. , 1.4, ..., 1. , 0. , 0. ],
#        [4.7, 3.2, 1.3, ..., 1. , 0. , 0. ],
#        ...,
#        [6.5, 3. , 5.2, ..., 0. , 0. , 1. ],
#        [6.2, 3.4, 5.4, ..., 0. , 0. , 1. ],
#        [5.9, 3. , 5.1, ..., 0. , 0. , 1. ]])

# %%
# Pilih 4 kolom pertama untuk dijadikan sebagai atribut
X = dataset[:,0:4]
# Pilih 3 kolom terakhir sebagai label
y = dataset[:,4:7]

# %%
# Normalize
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2)

# %%
model = Sequential([    
                    Dense(64, activation='relu',  input_shape=(4,)),    
                    Dense(64, activation='relu'),    
                    Dense(3, activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_38 (Dense)            (None, 64)                320
#
#  dense_39 (Dense)            (None, 64)                4160
#
#  dense_40 (Dense)            (None, 3)                 195
#
# ...
# Total params: 4,675
# Trainable params: 4,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1852 - accuracy: 0.3417
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9871 - accuracy: 0.3917
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9369 - accuracy: 0.5333
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8777 - accuracy: 0.6583
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8219 - accuracy: 0.6583
# Epoch 6/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7645 - accuracy: 0.8583
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7204 - accuracy: 0.9583
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6760 - accuracy: 0.9500
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6329 - accuracy: 0.9250
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, Y_test)
# Out:
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0546 - accuracy: 1.0000
# [0.05455214902758598, 1.0]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='lower right')
plt.show()

# %%
import joblib

# %%
joblib.dump((model, min_max_scaler), "iris-classification-mlp.pkl")
# Out:
# ['iris-classification-mlp.pkl']
